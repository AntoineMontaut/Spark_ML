# %% [markdown]
# # Yelp Recommender
#
# ## Intro
#
# The purpose of this exercise is to use Spark in a real dataset, instead of just a toy example.
#
# You will use the data from the [Yelp Dataset Challenge](https://www.yelp.de/dataset_challenge), which contains information about businesses, users, reviews and more.
#
# For this exercise, you will need to focus only on the following files:
# - yelp_academic_dataset_business.json
# - yelp_academic_dataset_review.json
#
# The goal is to build a recommender using Spark's ALS (Alternating Least Squares) and then generate recommendations for a given user.
#
# Since the dataset is quite big, you should pick a business category (e.g. Restaurants) and a city (e.g. Edinburgh) and work on the recommender using only this subset of the data.
#
# Please take some time to:
# - find out what information you will need to feed as input to Spark's ALS
# - check how this information is available in the dataset
# - plan how you will tackle this problem

# %%
from pyspark import SparkContext, SQLContext
sc = SparkContext('local[*]')
sqlc = SQLContext(sc)

# %% [markdown]
# ## Business Data
#
# - Load the file ***yelp_academic_dataset_business.json*** and select the following columns:
#     - business_id
#     - name
#     - city
#     - stars
#     - categories
#     - address

# %%
df_business = sqlc.read.json('./yelp_academic_dataset_business.json')
df_business = df_business.select(['business_id', 
                   'name',
                   'city',
                   'stars',
                   'categories',
                   'address'])

# %%
df_business.take(1)
# Out:
# [Row(business_id='0DI8Dt2PJp07XkVvIElIcQ', name='Innovative Vapors', city='Tempe', stars=4.5, categories=['Tobacco Shops', 'Nightlife', 'Vape Shops', 'Shopping'], address='227 E Baseline Rd, Ste J2')]

# %%
# categories = df_business.select('categories')
# categories = []
# for lst in df_business.select('categories'):
#     for cat in lst:
#         if cat not in categories:
#             categories.append(cat)
            
categories_distinct = df_business.select('categories').rdd.flatMap(lambda x: x.categories if x.categories else []).distinct().collect()
categories_distinct.sort()
categories_distinct
# Out:
# ['& Probates',
#  '3D Printing',
#  'ATV Rentals/Tours',
#  'Acai Bowls',
#  'Accessories',
#  'Accountants',
#  'Acne Treatment',
#  'Active Life',
#  'Acupuncture',
#  'Addiction Medicine',
#  'Adoption Services',
#  'Adult',
#  'Adult Education',
#  'Adult Entertainment',
#  'Advertising',
#  'Aerial Fitness',
#  'Aerial Tours',
#  'Afghan',
#  'African',
#  'Agriturismi',
#  'Air Duct Cleaning',
#  'Aircraft Dealers',
#  'Aircraft Repairs',
#  'Airlines',
#  'Airport Lounges',
#  'Airport Shuttles',
#  'Airport Terminals',
#  'Airports',
#  'Airsoft',
#  'Allergists',
#  'Alsatian',
#  'Amateur Sports Teams',
#  'American (New)',
#  'American (Traditional)',
#  'Amusement Parks',
#  'Anesthesiologists',
#  'Animal Physical Therapy',
#  'Animal Shelters',
#  'Antiques',
#  'Apartments',
#  'Appliances',
#  'Appliances & Repair',
#  'Appraisal Services',
#  'Aquarium Services',
#  'Aquariums',
#  'Arabian',
#  'Arcades',
#  'Archery',
#  'Architects',
#  'Architectural Tours',
#  'Argentine',
#  'Armenian',
#  'Art Classes',
#  'Art Galleries',
#  'Art Museums',
#  'Art Restoration',
#  'Art Schools',
#  'Art Space Rentals',
#  'Art Supplies',
#  'Art Tours',
#  'Artificial Turf',
#  'Arts & Crafts',
#  'Arts & Entertainment',
#  'Asian Fusion',
#  'Assisted Living Facilities',
#  'Attraction Farms',
#  'Auction Houses',
#  'Audiologist',
#  'Australian',
#  'Austrian',
#  'Auto Customization',
#  'Auto Detailing',
#  'Auto Electric Services',
#  'Auto Glass Services',
#  'Auto Insurance',
#  'Auto Loan Providers',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'Auto Security',
#  'Auto Upholstery',
#  'Automotive',
#  'Awnings',
#  'Ayurveda',
#  'Baby Gear & Furniture',
#  'Backflow Services',
#  'Backshop',
#  'Baden',
#  'Badminton',
#  'Bagels',
#  'Bail Bondsmen',
#  'Bakeries',
#  'Bangladeshi',
#  'Bankruptcy Law',
#  'Banks & Credit Unions',
#  'Bar Crawl',
#  'Barbeque',
#  'Barbers',
#  'Barre Classes',
#  'Bars',
#  'Bartenders',
#  'Bartending Schools',
#  'Baseball Fields',
#  'Basketball Courts',
#  'Basque',
#  'Battery Stores',
#  'Batting Cages',
#  'Bavarian',
#  'Beach Bars',
#  'Beach Equipment Rentals',
#  'Beaches',
#  'Beauty & Spas',
#  'Bed & Breakfast',
#  'Beer',
#  'Beer Bar',
#  'Beer Garden',
#  'Beer Gardens',
#  'Beer Hall',
#  'Beer Tours',
#  'Belgian',
#  'Bespoke Clothing',
#  'Beverage Store',
#  'Bicycles',
#  'Bike Rentals',
#  'Bike Repair',
#  'Bike Repair/Maintenance',
#  'Bike Sharing',
#  'Bike Shop',
#  'Bikes',
#  'Bingo Halls',
#  'Bird Shops',
#  'Bistros',
#  'Blood & Plasma Donation Centers',
#  'Blow Dry/Out Services',
#  'Boat Charters',
#  'Boat Dealers',
#  'Boat Repair',
#  'Boat Tours',
#  'Boating',
#  'Body Shops',
#  'Bookbinding',
#  'Bookkeepers',
#  'Books',
#  'Bookstores',
#  'Boot Camps',
#  'Botanical Gardens',
#  'Bowling',
#  'Boxing',
#  'Brasseries',
#  'Brazilian',
#  'Brazilian Jiu-jitsu',
#  'Breakfast & Brunch',
#  'Breweries',
#  'Brewing Supplies',
#  'Bridal',
#  'British',
#  'Bubble Soccer',
#  'Bubble Tea',
#  'Buddhist Temples',
#  'Buffets',
#  'Building Supplies',
#  'Bulgarian',
#  'Burgers',
#  'Burmese',
#  'Bus Tours',
#  'Buses',
#  'Business Consulting',
#  'Business Law',
#  'Butcher',
#  'CPR Classes',
#  'CSA',
#  'Cabaret',
#  'Cabinetry',
#  'Cable Cars',
#  'Cafes',
#  'Cafeteria',
#  'Cajun/Creole',
#  'Calligraphy',
#  'Cambodian',
#  'Campgrounds',
#  'Canadian (New)',
#  'Candy Stores',
#  'Cannabis Clinics',
#  'Cannabis Dispensaries',
#  'Cannabis Tours',
#  'Cantonese',
#  'Car Auctions',
#  'Car Brokers',
#  'Car Buyers',
#  'Car Dealers',
#  'Car Inspectors',
#  'Car Rental',
#  'Car Share Services',
#  'Car Stereo Installation',
#  'Car Wash',
#  'Car Window Tinting',
#  'Cardio Classes',
#  'Cardiologists',
#  'Cards & Stationery',
#  'Career Counseling',
#  'Caribbean',
#  'Caricatures',
#  'Carousels',
#  'Carpenters',
#  'Carpet Cleaning',
#  'Carpet Installation',
#  'Carpeting',
#  'Casinos',
#  'Castles',
#  'Caterers',
#  'Challenge Courses',
#  'Champagne Bars',
#  'Check Cashing/Pay-day Loans',
#  'Cheese Shops',
#  'Cheesesteaks',
#  'Chicken Shop',
#  'Chicken Wings',
#  'Child Care & Day Care',
#  'Childbirth Education',
#  'Childproofing',
#  "Children's Clothing",
#  "Children's Museums",
#  'Chimney Sweeps',
#  'Chinese',
#  'Chiropractors',
#  'Chocolatiers & Shops',
#  'Choirs',
#  'Christmas Markets',
#  'Christmas Trees',
#  'Churches',
#  'Cideries',
#  'Cinema',
#  'Circuit Training Gyms',
#  'Civic Center',
#  'Climbing',
#  'Clock Repair',
#  'Clothing Rental',
#  'Clowns',
#  'Club Crawl',
#  'Cocktail Bars',
#  'Coffee & Tea',
#  'Coffee & Tea Supplies',
#  'Coffee Roasteries',
#  'Coffeeshops',
#  'College Counseling',
#  'Colleges & Universities',
#  'Colombian',
#  'Colonics',
#  'Comedy Clubs',
#  'Comfort Food',
#  'Comic Books',
#  'Commercial Real Estate',
#  'Commercial Truck Dealers',
#  'Commercial Truck Repair',
#  'Commissioned Artists',
#  'Community Centers',
#  'Community Gardens',
#  'Community Service/Non-Profit',
#  'Computers',
#  'Concept Shops',
#  'Concierge Medicine',
#  'Condominiums',
#  'Contract Law',
#  'Contractors',
#  'Convenience Stores',
#  'Cooking Classes',
#  'Cooking Schools',
#  'Cosmetic Dentists',
#  'Cosmetic Surgeons',
#  'Cosmetics & Beauty Supply',
#  'Cosmetology Schools',
#  'Costumes',
#  'Counseling & Mental Health',
#  'Countertop Installation',
#  'Country Clubs',
#  'Country Dance Halls',
#  'Couriers & Delivery Services',
#  'Courthouses',
#  'Cremation Services',
#  'Creperies',
#  'Criminal Defense Law',
#  'Cryotherapy',
#  'Cuban',
#  'Cultural Center',
#  'Cupcakes',
#  'Currency Exchange',
#  'Curry Sausage',
#  'Custom Cakes',
#  'Customized Merchandise',
#  'Cycling Classes',
#  'Czech',
#  'Czech/Slovakian',
#  'DIY Auto Shop',
#  'DJs',
#  'DUI Law',
#  'Damage Restoration',
#  'Dance Clubs',
#  'Dance Schools',
#  'Dance Studios',
#  'Dance Wear',
#  'Data Recovery',
#  'Day Camps',
#  'Day Spas',
#  'Debt Relief Services',
#  'Decks & Railing',
#  'Delicatessen',
#  'Delis',
#  'Demolition Services',
#  'Dental Hygienists',
#  'Dentists',
#  'Department Stores',
#  'Departments of Motor Vehicles',
#  'Dermatologists',
#  'Desserts',
#  'Diagnostic Imaging',
#  'Diagnostic Services',
#  'Dialysis Clinics',
#  'Dietitians',
#  'Digitizing Services',
#  'Dim Sum',
#  'Diners',
#  'Dinner Theater',
#  'Disc Golf',
#  'Discount Store',
#  'Distilleries',
#  'Dive Bars',
#  'Dive Shops',
#  'Diving',
#  'Divorce & Family Law',
#  'Do-It-Yourself Food',
#  'Doctors',
#  'Dog Parks',
#  'Dog Walkers',
#  'Dominican',
#  'Donairs',
#  'Donuts',
#  'Door Sales/Installation',
#  'Doulas',
#  'Drive-In Theater',
#  'Drive-Thru Bars',
#  'Driving Schools',
#  'Drugstores',
#  'Dry Cleaning',
#  'Dry Cleaning & Laundry',
#  'Drywall Installation & Repair',
#  'Dumpster Rental',
#  'Duplication Services',
#  'Duty-Free Shops',
#  'Ear Nose & Throat',
#  'Eastern European',
#  'Editorial Services',
#  'Education',
#  'Educational Services',
#  'Egyptian',
#  'Electricians',
#  'Electronics',
#  'Electronics Repair',
#  'Elementary Schools',
#  'Embassy',
#  'Embroidery & Crochet',
#  'Emergency Medicine',
#  'Emergency Pet Hospital',
#  'Emergency Rooms',
#  'Empanadas',
#  'Employment Agencies',
#  'Employment Law',
#  'Endocrinologists',
#  'Endodontists',
#  'Engraving',
#  'Environmental Abatement',
#  'Environmental Testing',
#  'Erotic Massage',
#  'Escape Games',
#  'Estate Liquidation',
#  'Estate Planning Law',
#  'Ethic Grocery',
#  'Ethiopian',
#  'Ethnic Food',
#  'Ethnic Grocery',
#  'Event Photography',
#  'Event Planning & Services',
#  'Eyebrow Services',
#  'Eyelash Service',
#  'Eyewear & Opticians',
#  'Fabric Stores',
#  'Face Painting',
#  'Falafel',
#  'Family Practice',
#  'Farm Equipment Repair',
#  'Farmers Market',
#  'Farming Equipment',
#  'Farms',
#  'Fashion',
#  'Fast Food',
#  'Fences & Gates',
#  'Fencing Clubs',
#  'Feng Shui',
#  'Fertility',
#  'Festivals',
#  'Filipino',
#  'Financial Advising',
#  'Financial Services',
#  'Fingerprinting',
#  'Fire Departments',
#  'Fire Protection Services',
#  'Firearm Training',
#  'Fireplace Services',
#  'Firewood',
#  'Fireworks',
#  'First Aid Classes',
#  'Fischbroetchen',
#  'Fish & Chips',
#  'Fishing',
#  'Fishmonger',
#  'Fitness & Instruction',
#  'Fitness/Exercise Equipment',
#  'Flatbread',
#  'Flea Markets',
#  'Flight Instruction',
#  'Float Spa',
#  'Flooring',
#  'Florists',
#  'Flowers',
#  'Flowers & Gifts',
#  'Flyboarding',
#  'Fondue',
#  'Food',
#  'Food Banks',
#  'Food Court',
#  'Food Delivery Services',
#  'Food Stands',
#  'Food Tours',
#  'Food Trucks',
#  'Formal Wear',
#  'Framing',
#  'Free Diving',
#  'French',
#  'Friterie',
#  'Fruits & Veggies',
#  'Fuel Docks',
#  'Fun Fair',
#  'Funeral Services & Cemeteries',
#  'Fur Clothing',
#  'Furniture Assembly',
#  'Furniture Rental',
#  'Furniture Repair',
#  'Furniture Reupholstery',
#  'Furniture Stores',
#  'Game Truck Rental',
#  'Garage Door Services',
#  'Gardeners',
#  'Gas & Service Stations',
#  'Gastroenterologist',
#  'Gastropubs',
#  'Gay Bars',
#  'Gelato',
#  'General Dentistry',
#  'General Festivals',
#  'General Litigation',
#  'Generator Installation/Repair',
#  'German',
#  'Gerontologists',
#  'Gift Shops',
#  'Glass & Mirrors',
#  'Gluten-Free',
#  'Go Karts',
#  'Gold Buyers',
#  'Golf',
#  'Golf Cart Rentals',
#  'Golf Equipment',
#  'Golf Equipment Shops',
#  'Golf Lessons',
#  'Graphic Design',
#  'Greek',
#  'Grilling Equipment',
#  'Grocery',
#  'Guest Houses',
#  'Guitar Stores',
#  'Gun/Rifle Ranges',
#  'Guns & Ammo',
#  'Gutter Services',
#  'Gymnastics',
#  'Gyms',
#  'Hainan',
#  'Hair Extensions',
#  'Hair Loss Centers',
#  'Hair Removal',
#  'Hair Salons',
#  'Hair Stylists',
#  'Haitian',
#  'Hakka',
#  'Halal',
#  'Halotherapy',
#  'Handyman',
#  'Hang Gliding',
#  'Hardware Stores',
#  'Hats',
#  'Haunted Houses',
#  'Hawaiian',
#  'Head Shops',
#  'Health & Medical',
#  'Health Insurance Offices',
#  'Health Markets',
#  'Health Retreats',
#  'Hearing Aid Providers',
#  'Hearing Aids',
#  'Heating & Air Conditioning/HVAC',
#  'Henna Artists',
#  'Hepatologists',
#  'Herbal Shops',
#  'Herbs & Spices',
#  'High Fidelity Audio Equipment',
#  'Hiking',
#  'Himalayan/Nepalese',
#  'Hindu Temples',
#  'Historical Tours',
#  'Hobby Shops',
#  'Holiday Decorating Services',
#  'Holiday Decorations',
#  'Holistic Animal Care',
#  'Home & Garden',
#  'Home & Rental Insurance',
#  'Home Automation',
#  'Home Cleaning',
#  'Home Decor',
#  'Home Energy Auditors',
#  'Home Health Care',
#  'Home Inspectors',
#  'Home Network Installation',
#  'Home Organization',
#  'Home Services',
#  'Home Staging',
#  'Home Theatre Installation',
#  'Home Window Tinting',
#  'Homeless Shelters',
#  'Homeowner Association',
#  'Hong Kong Style Cafe',
#  'Hookah Bars',
#  'Horse Boarding',
#  'Horse Equipment Shops',
#  'Horse Racing',
#  'Horseback Riding',
#  'Hospice',
#  'Hospitals',
#  'Hostels',
#  'Hot Air Balloons',
#  'Hot Dogs',
#  'Hot Pot',
#  'Hot Tub & Pool',
#  'Hotel bar',
#  'Hotels',
#  'Hotels & Travel',
#  'House Sitters',
#  'Hungarian',
#  'Hunting & Fishing Supplies',
#  'Hydro-jetting',
#  'Hydroponics',
#  'Hydrotherapy',
#  'Hypnosis/Hypnotherapy',
#  'IP & Internet Law',
#  'IT Services & Computer Repair',
#  'IV Hydration',
#  'Iberian',
#  'Ice Cream & Frozen Yogurt',
#  'Immigration Law',
#  'Immunodermatologists',
#  'Imported Food',
#  'Indian',
#  'Indonesian',
#  'Indoor Landscaping',
#  'Indoor Playcentre',
#  'Infectious Disease Specialists',
#  'Installment Loans',
#  'Insulation Installation',
#  'Insurance',
#  'Interior Design',
#  'Internal Medicine',
#  'International',
#  'International Grocery',
#  'Internet Cafes',
#  'Internet Service Providers',
#  'Interval Training Gyms',
#  'Investing',
#  'Irish',
#  'Irish Pub',
#  'Irrigation',
#  'Island Pub',
#  'Italian',
#  'Izakaya',
#  'Japanese',
#  'Japanese Curry',
#  'Jazz & Blues',
#  'Jet Skis',
#  'Jewelry',
#  'Jewelry Repair',
#  'Juice Bars & Smoothies',
#  'Junk Removal & Hauling',
#  'Junkyards',
#  'Karaoke',
#  'Karate',
#  'Kebab',
#  'Keys & Locksmiths',
#  'Kickboxing',
#  'Kids Activities',
#  'Kiosk',
#  'Kitchen & Bath',
#  'Knife Sharpening',
#  'Knitting Supplies',
#  'Kombucha',
#  'Korean',
#  'Kosher',
#  'LAN Centers',
#  'Laboratory Testing',
#  'Lactation Services',
#  'Lakes',
#  'Landmarks & Historical Buildings',
#  'Landscape Architects',
#  'Landscaping',
#  'Language Schools',
#  'Laotian',
#  'Laser Eye Surgery/Lasik',
#  'Laser Hair Removal',
#  'Laser Tag',
#  'Latin American',
#  'Laundromat',
#  'Laundry Services',
#  'Lawyers',
#  'Leather Goods',
#  'Lebanese',
#  'Legal Services',
#  'Leisure Centers',
#  'Libraries',
#  'Lice Services',
#  'Life Coach',
#  'Life Insurance',
#  'Lighting Fixtures & Equipment',
#  'Limos',
#  'Linens',
#  'Lingerie',
#  'Live/Raw Food',
#  'Livestock Feed & Supply',
#  'Local Fish Stores',
#  'Local Flavor',
#  'Local Services',
#  'Lounges',
#  'Luggage',
#  'Macarons',
#  'Machine & Tool Rental',
#  'Machine Shops',
#  'Magicians',
#  'Mags',
#  'Mailbox Centers',
#  'Makeup Artists',
#  'Malaysian',
#  'Marinas',
#  'Market Stalls',
#  'Marketing',
#  'Martial Arts',
#  'Masonry/Concrete',
#  'Mass Media',
#  'Massage',
#  'Massage Schools',
#  'Massage Therapy',
#  'Matchmakers',
#  'Maternity Wear',
#  'Mattresses',
#  'Meat Shops',
#  'Mediators',
#  'Medical Cannabis Referrals',
#  'Medical Centers',
#  'Medical Law',
#  'Medical Spas',
#  'Medical Supplies',
#  'Medical Transportation',
#  'Meditation Centers',
#  'Mediterranean',
#  "Men's Clothing",
#  "Men's Hair Salons",
#  'Metal Fabricators',
#  'Metro Stations',
#  'Mexican',
#  'Middle Eastern',
#  'Middle Schools & High Schools',
#  'Midwives',
#  'Milkshake Bars',
#  'Minho',
#  'Mini Golf',
#  'Mobile Dent Repair',
#  'Mobile Home Dealers',
#  'Mobile Home Parks',
#  'Mobile Phone Accessories',
#  'Mobile Phone Repair',
#  'Mobile Phones',
#  'Mobility Equipment Sales & Services',
#  'Modern European',
#  'Mongolian',
#  'Montessori Schools',
#  'Moroccan',
#  'Mortgage Brokers',
#  'Mortgage Lenders',
#  'Mortuary Services',
#  'Mosques',
#  'Motorcycle Dealers',
#  'Motorcycle Gear',
#  'Motorcycle Rental',
#  'Motorcycle Repair',
#  'Motorsport Vehicle Dealers',
#  'Motorsport Vehicle Repairs',
#  'Mountain Biking',
#  'Movers',
#  'Muay Thai',
#  'Mulled Wine',
#  'Museums',
#  'Music & DVDs',
#  'Music & Video',
#  'Music Production Services',
#  'Music Venues',
#  'Musical Instrument Services',
#  'Musical Instruments & Teachers',
#  'Musicians',
#  'Nail Salons',
#  'Nail Technicians',
#  'Nanny Services',
#  'Naturopathic/Holistic',
#  'Neurologist',
#  'Neuropathologists',
#  'Neurotologists',
#  'New Mexican Cuisine',
#  'Newspapers & Magazines',
#  'Nicaraguan',
#  'Nightlife',
#  'Noodles',
#  'Notaries',
#  'Nurse Practitioner',
#  'Nurseries & Gardening',
#  'Nursing Schools',
#  'Nutritionists',
#  'Observatories',
#  'Obstetricians & Gynecologists',
#  'Occupational Therapy',
#  'Office Cleaning',
#  'Office Equipment',
#  'Officiants',
#  'Oil Change Stations',
#  'Olive Oil',
#  'Oncologist',
#  'Opera & Ballet',
#  'Ophthalmologists',
#  'Optometrists',
#  'Oral Surgeons',
#  'Organic Stores',
#  'Oriental',
#  'Orthodontists',
#  'Orthopedists',
#  'Orthotics',
#  'Osteopathic Physicians',
#  'Osteopaths',
#  'Outdoor Furniture Stores',
#  'Outdoor Gear',
#  'Outlet Stores',
#  'Oxygen Bars',
#  'Packing Services',
#  'Packing Supplies',
#  'Paddleboarding',
#  'Pain Management',
#  'Paint & Sip',
#  'Paint Stores',
#  'Paint-Your-Own Pottery',
#  'Paintball',
#  'Painters',
#  'Pakistani',
#  'Palatine',
#  'Pan Asian',
#  'Parent Cafes',
#  'Parenting Classes',
#  'Parking',
#  'Parks',
#  'Party & Event Planning',
#  'Party Bike Rentals',
#  'Party Bus Rentals',
#  'Party Characters',
#  'Party Equipment Rentals',
#  'Party Supplies',
#  'Passport & Visa Services',
#  'Pasta Shops',
#  'Patent Law',
#  'Pathologists',
#  'Patio Coverings',
#  'Patisserie/Cake Shop',
#  'Pawn Shops',
#  'Payroll Services',
#  'Pediatric Dentists',
#  'Pediatricians',
#  'Pedicabs',
#  'Pensions',
#  'Performing Arts',
#  'Perfume',
#  'Periodontists',
#  'Permanent Makeup',
#  'Persian/Iranian',
#  'Personal Assistants',
#  'Personal Care Services',
#  'Personal Chefs',
#  'Personal Injury Law',
#  'Personal Shopping',
#  'Peruvian',
#  'Pest Control',
#  'Pet Adoption',
#  'Pet Boarding/Pet Sitting',
#  'Pet Breeders',
#  'Pet Cremation Services',
#  'Pet Groomers',
#  'Pet Hospice',
#  'Pet Insurance',
#  'Pet Photography',
#  'Pet Services',
#  'Pet Stores',
#  'Pet Training',
#  'Pet Transportation',
#  'Pets',
#  'Petting Zoos',
#  'Pharmacy',
#  'Phlebologists',
#  'Photo Booth Rentals',
#  'Photographers',
#  'Photography Stores & Services',
#  'Physical Therapy',
#  'Piano Bars',
#  'Piano Services',
#  'Piano Stores',
#  'Pick Your Own Farms',
#  'Piercing',
#  'Pilates',
#  'Pita',
#  'Pizza',
#  'Placenta Encapsulations',
#  'Planetarium',
#  'Playgrounds',
#  'Plumbing',
#  'Plus Size Fashion',
#  'Podiatrists',
#  'Poke',
#  'Pole Dancing Classes',
#  'Police Departments',
#  'Polish',
#  'Pool & Billiards',
#  'Pool & Hot Tub Service',
#  'Pool Cleaners',
#  'Pool Halls',
#  'Pop-Up Restaurants',
#  'Pop-up Shops',
#  'Popcorn Shops',
#  'Portuguese',
#  'Post Offices',
#  'Poutineries',
#  'Powder Coating',
#  'Prenatal/Perinatal Care',
#  'Preschools',
#  'Pressure Washers',
#  'Pretzels',
#  'Preventive Medicine',
#  'Print Media',
#  'Printing Services',
#  'Private Investigation',
#  'Private Jet Charter',
#  'Private Tutors',
#  'Process Servers',
#  'Proctologists',
#  'Product Design',
#  'Professional Services',
#  'Professional Sports Teams',
#  'Propane',
#  'Property Management',
#  'Prosthetics',
#  'Prosthodontists',
#  'Psychiatrists',
#  'Psychics & Astrologers',
#  'Psychologists',
#  'Pub Food',
#  'Public Art',
#  'Public Plazas',
#  'Public Relations',
#  'Public Services & Government',
#  'Public Transportation',
#  'Pubs',
#  'Puerto Rican',
#  'Pulmonologist',
#  'Pumpkin Patches',
#  'RV Dealers',
#  'RV Parks',
#  'RV Rental',
#  'RV Repair',
#  'Race Tracks',
#  'Races & Competitions',
#  'Racing Experience',
#  'Radio Stations',
#  'Radiologists',
#  'Rafting/Kayaking',
#  'Ramen',
#  'Ranches',
#  'Real Estate',
#  'Real Estate Agents',
#  'Real Estate Law',
#  'Real Estate Photography',
#  'Real Estate Services',
#  'Recording & Rehearsal Studios',
#  'Recreation Centers',
#  'Recycling Center',
#  'Refinishing Services',
#  'Reflexology',
#  'Registration Services',
#  'Rehabilitation Center',
#  'Reiki',
#  'Religious Items',
#  'Religious Organizations',
#  'Religious Schools',
#  'Reptile Shops',
#  'Resorts',
#  'Rest Stops',
#  'Restaurant Supplies',
#  'Restaurants',
#  'Retirement Homes',
#  'Reunion',
#  'Rheumatologists',
#  'Roadside Assistance',
#  'Rock Climbing',
#  'Rodeo',
#  'Rolfing',
#  'Roof Inspectors',
#  'Roofing',
#  'Rotisserie Chicken',
#  'Rugs',
#  'Russian',
#  'Sailing',
#  'Salad',
#  'Salvadoran',
#  'Sandblasting',
#  'Sandwiches',
#  'Saunas',
#  'Scandinavian',
#  'Scavenger Hunts',
#  'Scooter Tours',
#  'Scottish',
#  'Screen Printing',
#  'Screen Printing/T-Shirt Printing',
#  'Scuba Diving',
#  'Seafood',
#  'Seafood Markets',
#  'Security Services',
#  'Security Systems',
#  'Self Storage',
#  'Senegalese',
#  'Senior Centers',
#  'Septic Services',
#  'Serbo Croatian',
#  'Session Photography',
#  'Sewing & Alterations',
#  'Sex Therapists',
#  'Shades & Blinds',
#  'Shanghainese',
#  'Shared Office Spaces',
#  'Shaved Ice',
#  'Shaved Snow',
#  'Shipping Centers',
#  'Shoe Repair',
#  'Shoe Shine',
#  'Shoe Stores',
#  'Shopping',
#  'Shopping Centers',
#  'Shredding Services',
#  'Shutters',
#  'Signmaking',
#  'Singaporean',
#  'Skate Parks',
#  'Skate Shops',
#  'Skating Rinks',
#  'Ski & Snowboard Shops',
#  'Ski Resorts',
#  'Ski Schools',
#  'Skiing',
#  'Skilled Nursing',
#  'Skin Care',
#  'Skydiving',
#  'Sledding',
#  'Sleep Specialists',
#  'Slovakian',
#  'Smog Check Stations',
#  'Smokehouse',
#  'Snorkeling',
#  'Snow Removal',
#  'Soba',
#  'Soccer',
#  'Social Clubs',
#  'Software Development',
#  'Solar Installation',
#  'Solar Panel Cleaning',
#  'Soul Food',
#  'Soup',
#  'South African',
#  'Southern',
#  'Souvenir Shops',
#  ...]

# %%
cities_distinct = df_business.select('city').rdd.distinct().collect()
cities_distinct.sort()
cities_distinct
# Out:
# [Row(city=''),
#  Row(city='AGINCOURT'),
#  Row(city='Aberdour'),
#  Row(city='Aberlady'),
#  Row(city='Ahwahtukee'),
#  Row(city='Ahwatukee'),
#  Row(city='Ahwatukee Foothills Village'),
#  Row(city='Aichwald'),
#  Row(city='Ajax'),
#  Row(city='Alburg'),
#  Row(city='Allegheny'),
#  Row(city='Allison Park'),
#  Row(city='Ambridge'),
#  Row(city='Amherst'),
#  Row(city='Anjou'),
#  Row(city='Ansnorveldt'),
#  Row(city='Anthem'),
#  Row(city='Arlington'),
#  Row(city='Arnold'),
#  Row(city='Aspinwall'),
#  Row(city='Auburn'),
#  Row(city='Auburn Township'),
#  Row(city='Aurora'),
#  Row(city='Avalon'),
#  Row(city='Avon'),
#  Row(city='Avon Lake'),
#  Row(city='Avondale'),
#  Row(city="Baie-D'urfe"),
#  Row(city="Baie-d'Urfé"),
#  Row(city='Bainbridge'),
#  Row(city='Bainbridge Township'),
#  Row(city='Baldwin'),
#  Row(city='Balerno'),
#  Row(city='Ballantyne'),
#  Row(city='Banksville'),
#  Row(city='Bath'),
#  Row(city='Bathurst Quay'),
#  Row(city='Bay Village'),
#  Row(city='Beachwood'),
#  Row(city='Beaconsfield'),
#  Row(city='Bedford'),
#  Row(city='Bedford HTS'),
#  Row(city='Bedford Heights'),
#  Row(city='Bedford Hts.'),
#  Row(city='Beeton'),
#  Row(city='Belleville'),
#  Row(city='Bellevue'),
#  Row(city='Bellvue'),
#  Row(city='Belmont'),
#  Row(city='Beloeil'),
#  Row(city='Ben Avon'),
#  Row(city='Bentleyville'),
#  Row(city='Berea'),
#  Row(city='Berg'),
#  Row(city='Bernhausen'),
#  Row(city='Berry'),
#  Row(city='Bethel Park'),
#  Row(city='Black Earth'),
#  Row(city='Blackness'),
#  Row(city='Blainville'),
#  Row(city='Blawnox'),
#  Row(city='Bloomfield'),
#  Row(city='Blue Diamond'),
#  Row(city='Bois-Des-Filion'),
#  Row(city='Boisbriand'),
#  Row(city='Bolton'),
#  Row(city='Bonnyrigg'),
#  Row(city='Bonnyrigg and Lasswade'),
#  Row(city='Boston Heights'),
#  Row(city='Boucherville'),
#  Row(city='Boulder City'),
#  Row(city='Braddock'),
#  Row(city='Bradford'),
#  Row(city='Bradford West Gwillimbury'),
#  Row(city='Bradfordwoods'),
#  Row(city='Brampton'),
#  Row(city='Bratenahl'),
#  Row(city='Brecksville'),
#  Row(city='Brentwood'),
#  Row(city='Bridgeville'),
#  Row(city='Broadlands'),
#  Row(city='Broadview Heights'),
#  Row(city='Brook Park'),
#  Row(city='Brooklin'),
#  Row(city='Brookline'),
#  Row(city='Brooklyn'),
#  Row(city='Brooklyn Hts.'),
#  Row(city='Brookpark'),
#  Row(city='Brossard'),
#  Row(city='Broxburn'),
#  Row(city='Brunswick'),
#  Row(city='Brunswick Hills'),
#  Row(city='Bruntsfield'),
#  Row(city='Buckeye - Shaker'),
#  Row(city='Buena Vista'),
#  Row(city='Burntisland'),
#  Row(city='Burton'),
#  Row(city='CHARLOTTE'),
#  Row(city='Caledon'),
#  Row(city='Caledon East'),
#  Row(city='Caledon Village'),
#  Row(city='Candiac'),
#  Row(city='Canonsburg'),
#  Row(city='Carefree'),
#  Row(city='Carnegie'),
#  Row(city='Carnot-Moon'),
#  Row(city='Castle Shannon'),
#  Row(city='Cave Creek'),
#  Row(city='Cecil'),
#  Row(city='Centennial Hills'),
#  Row(city='Central City'),
#  Row(city='Central City Village'),
#  Row(city='Centre Island'),
#  Row(city='Chagrin Falls'),
#  Row(city='Chambly'),
#  Row(city='Champaign'),
#  Row(city='Champlain'),
#  Row(city='Chander'),
#  Row(city='Chandler'),
#  Row(city='Chardon'),
#  Row(city='Charlemagne'),
#  Row(city='Charlote'),
#  Row(city='Charlotte'),
#  Row(city='Charlotte (University)'),
#  Row(city='Chatauguay'),
#  Row(city='Chateau'),
#  Row(city='Chateauguay'),
#  Row(city='Chertsey'),
#  Row(city='Chesterland'),
#  Row(city='Cheswick'),
#  Row(city='Chomedey, Laval'),
#  Row(city='Churubusco'),
#  Row(city='Châteauguay'),
#  Row(city='City of Edinburgh'),
#  Row(city='Clairton'),
#  Row(city='Claremont'),
#  Row(city='Clark county'),
#  Row(city='Clarkson'),
#  Row(city='Cleveland'),
#  Row(city='Cleveland Heights'),
#  Row(city='Cleveland Hts'),
#  Row(city='Columbia Station'),
#  Row(city='Concord'),
#  Row(city='Concord Mills'),
#  Row(city='Concord Township'),
#  Row(city='Concord Twp'),
#  Row(city='Cooksville'),
#  Row(city='Copley'),
#  Row(city='Coraopolis'),
#  Row(city='Cornelius'),
#  Row(city='Cote Saint-Luc'),
#  Row(city='Cote-Saint-Luc'),
#  Row(city='Cottage Grove'),
#  Row(city='Cowdenbeath'),
#  Row(city='Crabtree'),
#  Row(city='Crafton'),
#  Row(city='Cramerton'),
#  Row(city='Cramond'),
#  Row(city='Cramond Bridge'),
#  Row(city='Creighton'),
#  Row(city='Crescent'),
#  Row(city='Cross Plains'),
#  Row(city='Cuddy'),
#  Row(city='Currie'),
#  Row(city='Cuyahoga Falls'),
#  Row(city='Cuyahoga Fls'),
#  Row(city='Cuyahoga Heights'),
#  Row(city='Côte-Saint-Luc'),
#  Row(city='Dalgety Bay'),
#  Row(city='Dalkeith'),
#  Row(city='Dallas'),
#  Row(city='Dane'),
#  Row(city='Davidson'),
#  Row(city='De Forest'),
#  Row(city='DeForest'),
#  Row(city='Delson'),
#  Row(city='Denkendorf'),
#  Row(city='Deux-Montagnes Regional County Municipality'),
#  Row(city='Dewey'),
#  Row(city='Ditzingen'),
#  Row(city='Dollard-Des Ormeaux'),
#  Row(city='Dollard-Des-Ormeaux'),
#  Row(city='Dollard-des-Ormeaux'),
#  Row(city='Don Mills'),
#  Row(city='Dormont'),
#  Row(city='Dorval'),
#  Row(city='Downsview'),
#  Row(city='Downtown'),
#  Row(city='Downtown Toronto'),
#  Row(city='Dravosburg'),
#  Row(city='Dunfermline'),
#  Row(city='E Gwillimbury'),
#  Row(city='East Cleveland'),
#  Row(city='East Credit'),
#  Row(city='East Gwilimbury'),
#  Row(city='East Gwillimbury'),
#  Row(city='East Liberty'),
#  Row(city='East Mc Keesport'),
#  Row(city='East McKeesport'),
#  Row(city='East Mesa'),
#  Row(city='East Pittsburgh'),
#  Row(city='East York'),
#  Row(city='Eastlake'),
#  Row(city='Edgewood'),
#  Row(city='Edgeworth'),
#  Row(city='Edimbourg'),
#  Row(city='Edinburgh'),
#  Row(city='Edinburgh City of'),
#  Row(city='El Mirage'),
#  Row(city='Elizabeth'),
#  Row(city='Elizabeth Township'),
#  Row(city='Elk Grove Villa'),
#  Row(city='Elrama'),
#  Row(city='Elyria'),
#  Row(city='Emsworth'),
#  Row(city='Enterprise'),
#  Row(city='Esslingen'),
#  Row(city='Esslingen am Neckar'),
#  Row(city='Estérel'),
#  Row(city='Etna'),
#  Row(city='Etobicoke'),
#  Row(city='Euclid'),
#  Row(city='Fabreville'),
#  Row(city='Fairlawn'),
#  Row(city='Fairport Harbor'),
#  Row(city='Fairview'),
#  Row(city='Fairview Park'),
#  Row(city='Farnham'),
#  Row(city='Fellbach'),
#  Row(city='Filderstadt'),
#  Row(city='Finleyville'),
#  Row(city='Firth of Forth'),
#  Row(city='Fitchburg'),
#  Row(city='Fitchburgh'),
#  Row(city='Fithian'),
#  Row(city='Forest Hills'),
#  Row(city='Fort  Mill'),
#  Row(city='Fort McDowell'),
#  Row(city='Fort Mill'),
#  Row(city='Fountain Hills'),
#  Row(city='Fountainbridge'),
#  Row(city='Fox Chapel'),
#  Row(city='Franklin Park'),
#  Row(city='Frazer'),
#  Row(city='Freiberg'),
#  Row(city='Ft. Mill'),
#  Row(city='Garfield Heights'),
#  Row(city='Gastonia'),
#  Row(city='Gates Mills'),
#  Row(city='Geauga'),
#  Row(city='Gelndale'),
#  Row(city='Georgetown'),
#  Row(city='Gerlingen'),
#  Row(city='Gibsonia'),
#  Row(city='Gifford'),
#  Row(city='Gilbert'),
#  Row(city='Glasgow'),
#  Row(city='Glassport'),
#  Row(city='Glbert'),
#  Row(city='Glen Williams'),
#  Row(city='Glendale'),
#  Row(city='Glenndale'),
#  Row(city='Glenrothes'),
#  Row(city='Glenshaw'),
#  Row(city='Godmanchester'),
#  Row(city='Goodwood'),
#  Row(city='Goodyear'),
#  Row(city='Gorebridge'),
#  Row(city='Gormley'),
#  Row(city='Grafton'),
#  Row(city='Grand River'),
#  Row(city='Green Tree'),
#  Row(city='Green Valley'),
#  Row(city='Greenfield Park'),
#  Row(city='Guadalupe'),
#  Row(city='Gullane'),
#  Row(city='Haddington'),
#  Row(city='Hampton Township'),
#  Row(city='Harmarville'),
#  Row(city='Harrisbug'),
#  Row(city='Harrisburg'),
#  Row(city='Harwick'),
#  Row(city='Hawthorne'),
#  Row(city='Heidelberg'),
#  Row(city='Hemmingen'),
#  Row(city='Hemmingford'),
#  Row(city='Henderson'),
#  Row(city='Hendersonville'),
#  Row(city='Henderston'),
#  Row(city='Hendserson'),
#  Row(city='Herminie'),
#  Row(city='Highland Heights'),
#  Row(city='Highland Hills'),
#  Row(city='Higley'),
#  Row(city='Hinckley'),
#  Row(city='Hiram'),
#  Row(city='Homer'),
#  Row(city='Homestead'),
#  Row(city='Houston'),
#  Row(city='Hudson'),
#  Row(city='Huntersville'),
#  Row(city='Huntingdon'),
#  Row(city='Huntsburg'),
#  Row(city='Imperial'),
#  Row(city='Independence'),
#  Row(city='Indian Hook'),
#  Row(city='Indian Land'),
#  Row(city='Indian Trail'),
#  Row(city='Indianola'),
#  Row(city='Inglewood'),
#  Row(city='Ingliston'),
#  Row(city='Ingram'),
#  Row(city='Inverkeithing'),
#  Row(city='Inverness'),
#  Row(city='Irwin'),
#  Row(city='Jefferson Hills'),
#  Row(city='Joliette'),
#  Row(city='Juniper Green'),
#  Row(city='Kahnawake'),
#  Row(city='Kannapolis'),
#  Row(city='Kennedy Township'),
#  Row(city='Kent'),
#  Row(city='Kernen'),
#  Row(city='Kernen im Remstal'),
#  Row(city='Kettleby'),
#  Row(city='King'),
#  Row(city='King City'),
#  Row(city='Kingussie'),
#  Row(city='Kirkcaldy'),
#  Row(city='Kirkland'),
#  Row(city='Kirknewton'),
#  Row(city='Kirtland'),
#  Row(city='Kleinburg'),
#  Row(city='Korntal-Münchingen'),
#  Row(city='Kornwestheim'),
#  Row(city="L'assomption"),
#  Row(city="L'ile-Perrot"),
#  Row(city="L'Île-Perrot"),
#  Row(city="L'Île-Perrôt"),
#  Row(city='La Prairie'),
#  Row(city='La Salle'),
#  Row(city='LaSalle'),
#  Row(city='Lachenaie'),
#  Row(city='Lachine'),
#  Row(city='Lachute'),
#  Row(city='Lacolle'),
#  Row(city='Lagrange'),
#  Row(city='Lake Las Vegas'),
#  Row(city='Lake Park'),
#  Row(city='Lake Wylie'),
#  Row(city='Lakewood'),
#  Row(city='Lambton'),
#  Row(city='Las  Vegas'),
#  Row(city='Las Vegas'),
#  Row(city='Las Vegas East'),
#  Row(city='Las Vegas NV'),
#  Row(city='Las Vegas Strip'),
#  Row(city='Las Vegass'),
#  Row(city='Las vegas'),
#  Row(city='LasVegas'),
#  Row(city='Lasalle'),
#  Row(city='Lasswade'),
#  Row(city='Laval'),
#  Row(city='Laveen'),
#  Row(city='Laveen Village'),
#  Row(city='Lawrence'),
#  Row(city='Le Sud-Ouest'),
#  Row(city='Leaside'),
#  Row(city='Leetsdale'),
#  Row(city='Leinfelden'),
#  Row(city='Leinfelden-Echterdingen'),
#  Row(city='Leith'),
#  Row(city='Leonberg'),
#  Row(city='Leslieville'),
#  Row(city='Liberty'),
#  Row(city='Library'),
#  Row(city='Litchfield'),
#  Row(city='Litchfield Park'),
#  Row(city='Livingston'),
#  Row(city='Loanhead'),
#  Row(city='London'),
#  Row(city='Longniddry'),
#  Row(city='Longueuil'),
#  Row(city='Lorain'),
#  Row(city='Lothian'),
#  Row(city='Lowell'),
#  Row(city='Lower Burrell'),
#  Row(city='Lower Lawrenceville'),
#  Row(city='Lowesville'),
#  Row(city='Ludwigsburg'),
#  Row(city='Lyndhurst'),
#  Row(city='MC Murray'),
#  Row(city='MESA'),
#  Row(city='Macedonia'),
#  Row(city='Madison'),
#  Row(city='Madison WI'),
#  Row(city='Mahomet'),
#  Row(city='Malton'),
#  Row(city='Mansfield'),
#  Row(city='Mantua'),
#  Row(city='Maple'),
#  Row(city='Maple Grove'),
#  Row(city='Maple Heights'),
#  Row(city='Markham'),
#  Row(city='Mascouche'),
#  Row(city='Mathews'),
#  Row(city='Mattews'),
#  Row(city='Matthews'),
#  Row(city='Mayfield'),
#  Row(city='Mayfield Heights'),
#  Row(city='Mayfield Heights (Cleveland)'),
#  Row(city='Mayfield Hts'),
#  Row(city='Mayfield Hts.'),
#  Row(city='Mayfield Village'),
#  Row(city='Mc Donald'),
#  Row(city='Mc Farland'),
#  Row(city='Mc Murray'),
#  Row(city='McAdenville'),
#  Row(city='McCandless'),
#  Row(city='McCandless Township'),
#  Row(city='McDonald'),
#  Row(city='McFarland'),
#  Row(city='McKees Rocks'),
#  Row(city='McKeesport'),
#  Row(city='McKnight'),
#  Row(city='McMasterville'),
#  Row(city='McMurray'),
#  Row(city='McMurry'),
#  Row(city='Mccandless Township'),
#  Row(city='Mcmurray'),
#  Row(city='Median'),
#  Row(city='Medina'),
#  Row(city='Medina Township'),
#  Row(city='Mentor'),
#  Row(city='Mentor On the'),
#  Row(city='Mentor On the Lake'),
#  Row(city='Mentor-on-the-Lake'),
#  Row(city='Mercier'),
#  Row(city='Mesa'),
#  Row(city='Mesa AZ'),
#  Row(city='Mesa Arizona'),
#  Row(city='Middleburg Heights'),
#  Row(city='Middleburg Hts'),
#  Row(city='Middlefield'),
#  Row(city='Middleton'),
#  Row(city='Midland'),
#  Row(city='Midlothian'),
#  Row(city='Millvale'),
#  Row(city='Mint  Hill'),
#  Row(city='Mint Hill'),
#  Row(city='Mirabel'),
#  Row(city='Missisauga'),
#  Row(city='Mississauaga'),
#  Row(city='Mississauga'),
#  Row(city='Mississuaga'),
#  Row(city='Monona'),
#  Row(city='Monongahela'),
#  Row(city='Monoroeville'),
#  Row(city='Monreoville'),
#  Row(city='Monroeville'),
#  Row(city='Mont-Royal'),
#  Row(city='Mont-Saint-Gregoire'),
#  Row(city='Mont-Saint-Hilaire'),
#  Row(city='Monticello'),
#  Row(city='Montral'),
#  Row(city='Montreal'),
#  Row(city='Montreal-Nord'),
#  Row(city='Montreal-Ouest'),
#  Row(city='Montreal-West'),
#  Row(city='Montrose'),
#  Row(city='Montréal'),
#  Row(city='Montréal (Québec)'),
#  Row(city='Montréal-Nord'),
#  Row(city='Montréal-Ouest'),
#  Row(city='Montéal'),
#  Row(city='Mooers'),
#  Row(city='Moon'),
#  Row(city='Moon Township'),
#  Row(city='Moon Twp'),
#  Row(city='Moon Twp.'),
#  Row(city='Moreland Hills'),
#  Row(city='Morin-Heights'),
#  Row(city='Morriston'),
#  Row(city='Mount Albert'),
#  Row(city='Mount Holly'),
#  Row(city='Mount Horeb'),
#  Row(city='Mount Lebanon'),
#  Row(city='Mount Royal'),
#  Row(city='Mount Washington'),
#  Row(city='Mt Albert'),
#  Row(city='Mt Lebanon'),
#  Row(city='Mt. Horeb'),
#  Row(city='Mt. Lebanon'),
#  Row(city='Munhall'),
#  Row(city='Municipality of Murrysville'),
#  Row(city='Munroe Falls'),
#  Row(city='Murrysville'),
#  Row(city='Musselburgh'),
#  Row(city='Möglingen'),
#  Row(city='N E Las Vegas'),
#  Row(city='N Las Vegas'),
#  Row(city='N Ridgeville'),
#  Row(city='N W Las Vegas'),
#  Row(city='N. Las Vegas'),
#  Row(city='N. OLMSTED'),
#  Row(city='N. Olmsted'),
#  Row(city='N. Randall'),
#  Row(city='N. Ridgeville'),
#  Row(city='NORTH YORK'),
#  Row(city='Napierville'),
#  Row(city='Nellis AFB'),
#  Row(city='Nellis Afb'),
#  Row(city='Nellis Air Force Base'),
#  Row(city='Neville Island'),
#  Row(city='New Eagle'),
#  Row(city='New Kensington'),
#  Row(city='New Town'),
#  Row(city='Newbridge'),
#  Row(city='Newburgh Heights'),
#  Row(city='Newbury'),
#  Row(city='Newhaven'),
#  Row(city='Newington'),
#  Row(city='Newmarket'),
#  Row(city='Nobleton'),
#  Row(city='Nord'),
#  Row(city='North Huntingdon'),
#  Row(city='North Las Vegas'),
#  Row(city='North Olmstead'),
#  Row(city='North Olmsted'),
#  Row(city='North Olmsted,'),
#  Row(city='North Queensferry'),
#  Row(city='North Randall'),
#  Row(city='North Ridgeville'),
#  Row(city='North Royalton'),
#  Row(city='North Toronto'),
#  Row(city='North Versailles'),
#  Row(city='North York'),
#  Row(city='Northfield'),
#  Row(city='Northfield Center'),
#  Row(city='Northfield Center Township'),
#  Row(city='Northside'),
#  Row(city='Norval'),
#  Row(city="Notre-Dame-De-L'ile-Perrot"),
#  Row(city='Nottingham'),
#  Row(city='Novelty'),
#  Row(city='Noyan'),
#  Row(city='Oakdale'),
#  Row(city='Oakland'),
#  Row(city='Oakmont'),
#  Row(city='Oakville'),
#  Row(city='Oakwood Village'),
#  Row(city='Ogden'),
#  Row(city='Oka'),
#  Row(city='Old Town'),
#  Row(city='Olmsted Falls'),
#  Row(city='Olmsted Township'),
#  Row(city='Orange'),
#  Row(city='Oregon'),
#  Row(city='Ormstown'),
#  Row(city='Ostfildern'),
#  Row(city='Outremont'),
#  Row(city='Painesville'),
#  Row(city='Palmerston'),
#  Row(city='Paoli'),
#  Row(city='Paradise'),
#  Row(city='Paradise Valley'),
#  Row(city='Parma'),
#  Row(city='Parma Heights'),
#  Row(city='Paw Creek'),
#  Row(city='Pencaitland'),
#  Row(city='Penicuik'),
#  Row(city='Peninsula'),
#  Row(city='Penn Hills'),
#  Row(city='Peoria'),
#  Row(city='Pepper Pike'),
#  Row(city='Pheonix'),
#  Row(city='Pheonix AZ'),
#  Row(city='Philo'),
#  Row(city='Phoenix'),
#  Row(city='Phoenix AZ'),
#  Row(city='Phoenix,'),
#  Row(city='Phoneix'),
#  Row(city='Pickering'),
#  Row(city='Piedmont'),
#  Row(city='Pierrefonds'),
#  Row(city='Pincourt'),
#  Row(city='Pineville'),
#  Row(city='Pitcairn'),
#  Row(city='Pittsburch'),
#  Row(city='Pittsburgh'),
#  Row(city='Pleasant Hills'),
#  Row(city='Plieningen'),
#  Row(city='Plum'),
#  Row(city='Point Claire'),
#  Row(city='Pointe Claire'),
#  Row(city='Pointe-Aux-Trembles'),
#  Row(city='Pointe-Claire'),
#  Row(city='Port Credit'),
#  Row(city='Portobello'),
#  Row(city='Presto'),
#  Row(city='Prestonpans'),
#  Row(city='Quartermile'),
#  Row(city='Queensferry'),
#  Row(city='Rankin'),
#  Row(city='Ranlo'),
#  Row(city='Rantoul'),
#  Row(city='Ratho'),
#  Row(city='Rawdon'),
#  Row(city='Regent Square'),
#  Row(city='Reminderville'),
#  Row(city='Remseck'),
#  Row(city='Remseck am Neckar'),
#  Row(city='Repentigny'),
#  Row(city='Rexdale'),
#  Row(city='Richfield'),
#  Row(city='Richmond Heights'),
#  Row(city='Richmond Hil'),
#  Row(city='Richmond Hill'),
#  Row(city='Richmond Hts'),
#  Row(city='Rigaud'),
#  Row(city='Rillton'),
#  Row(city='Robinson'),
#  Row(city='Robinson Township'),
#  Row(city='Robinson Twp.'),
#  Row(city='Rocky River'),
#  Row(city='Roosevelt'),
#  Row(city='Rosemere'),
#  Row(city='Rosemère'),
#  Row(city='Roslin'),
#  Row(city='Ross'),
#  Row(city='Ross Township'),
#  Row(city='Rouses Point'),
#  Row(city='Roxboro'),
#  Row(city='Rural Ridge'),
#  Row(city='Russell Twp'),
#  Row(city='Russellton'),
#  Row(city='S Concord'),
#  Row(city='SCOTTSDALE AZ'),
#  Row(city='SLOAN'),
#  Row(city='Sagamore Hills'),
#  Row(city='Saint - Hyacinthe'),
#  Row(city='Saint Anns'),
#  Row(city='Saint Joseph'),
#  Row(city='Saint Laurent'),
#  Row(city='Saint Leonard'),
#  Row(city='Saint-Basile-Le-Grand'),
#  Row(city='Saint-Bernard-De-Lacolle'),
#  Row(city='Saint-Bernard-de-Lacolle'),
#  Row(city='Saint-Bruno'),
#  Row(city='Saint-Bruno-de-Montarville'),
#  Row(city='Saint-Constant'),
#  Row(city='Saint-Eustache'),
#  Row(city='Saint-Henri'),
#  Row(city='Saint-Hippolyte'),
#  Row(city='Saint-Hubert'),
#  Row(city='Saint-Hyacinthe'),
#  Row(city='Saint-Jean-Sur-Richelieu'),
#  Row(city='Saint-Jean-sur-Richelieu'),
#  Row(city='Saint-Jerome'),
#  Row(city='Saint-Jérôme'),
#  Row(city='Saint-Lambert'),
#  Row(city='Saint-Laurent'),
#  Row(city='Saint-Lazare'),
#  Row(city='Saint-Leonard'),
#  Row(city='Saint-Marc-Sur-Richelieu'),
#  Row(city='Saint-Marc-sur-Richelieu'),
#  Row(city='Saint-Pierre-de-Véronne-à-Pike-River'),
#  Row(city="Saint-Roch-De-L'achigan"),
#  Row(city='Saint-Sauveur'),
#  Row(city='Saint-Sauveur-des-Monts'),
#  Row(city='Sainte-Adele'),
#  Row(city='Sainte-Adèle'),
#  Row(city='Sainte-Anne-De-Bellevue'),
#  Row(city='Sainte-Anne-de-Bellevue'),
#  Row(city='Sainte-Anne-des-Plaines'),
#  Row(city='Sainte-Catherine'),
#  Row(city='Sainte-Dorothée'),
#  Row(city='Sainte-Genevieve'),
#  Row(city='Sainte-Julie'),
#  Row(city='Sainte-Madeleine'),
#  Row(city='Sainte-Marguerite-du-Lac-Masson'),
#  Row(city='Sainte-Marthe'),
#  Row(city='Sainte-Therese'),
#  Row(city='Sainte-Therese-de-Blainville'),
#  Row(city='Sainte-Thérèse'),
#  Row(city='Sainte-thérèse'),
#  Row(city='Salaberry-De-Valleyfield'),
#  Row(city='San Tan'),
#  Row(city='San Tan Valley'),
#  Row(city='Savoy'),
#  Row(city='Scarborough'),
#  Row(city='Scarbrough'),
#  Row(city='Scaroborough'),
#  Row(city='Scarobrough'),
#  Row(city='Schomberg'),
#  Row(city='Schwaikheim'),
#  Row(city='Schwieberdingen'),
#  Row(city='Schönaich'),
#  Row(city='Scotesdale'),
#  Row(city='Scotland'),
#  Row(city='Scott Township'),
#  Row(city='Scottdale'),
#  Row(city='Scottsadale'),
#  Row(city='Scottsdale'),
#  Row(city='Scottsdale AZ'),
#  Row(city='Seven Hills'),
#  Row(city='Sewickley'),
#  Row(city='Shady Side'),
#  Row(city='Shadyside'),
#  Row(city='Shaker Heights'),
#  Row(city='Shaker Hts'),
#  Row(city='Shaler Township'),
#  Row(city='Sharpsburg'),
#  Row(city='Sheffield'),
#  Row(city='Sheffield Lake'),
#  Row(city='Sheffield Village'),
#  Row(city='Shorewood Hills'),
#  Row(city='Side Slopes'),
#  Row(city='Sidney'),
#  Row(city='Silver Lake'),
#  Row(city='Sindelfingen'),
#  Row(city='Sloan'),
#  Row(city='Solon'),
#  Row(city='South Amherst'),
#  Row(city='South Euclid'),
#  Row(city='South Gyle'),
#  Row(city='South Hills'),
#  Row(city='South Las Vegas'),
#  Row(city='South Mountain'),
#  Row(city='South Park'),
#  Row(city='South Park Township'),
#  Row(city='South Queensferry'),
#  Row(city='Southside Flats'),
#  Row(city='Spring Hill City View'),
#  Row(city='Spring Valley'),
#  Row(city='Springdale'),
#  Row(city='Squirrel Hill'),
#  Row(city='St Bernard de Lacolle'),
#  Row(city='St Joseph'),
#  Row(city='St Leonard'),
#  Row(city='St Philippe de Laprairie'),
#  Row(city='St-Benoît de Mirabel'),
#  Row(city='St-Eugène'),
#  Row(city='St-Jerome'),
#  Row(city='St-Laurent'),
#  Row(city='St-Lazare'),
#  Row(city='St-Leonard'),
#  Row(city='St. Anns'),
#  Row(city='St. Jean Sur Richelieu'),
#  Row(city='St. Joseph'),
#  Row(city='Stallings'),
#  Row(city='Stanley'),
#  Row(city='Ste-Therese-de-Blainville'),
#  Row(city='Steinenbronn'),
#  Row(city='Stockbridge'),
#  Row(city='Stoney Creek'),
#  Row(city='Stouffville'),
#  Row(city='Stoughton'),
#  Row(city='Stow'),
#  Row(city='Stowe'),
#  Row(city='Stowe Township'),
#  Row(city='Straiton'),
#  Row(city='Streetsboro'),
#  Row(city='Streetsville'),
#  Row(city='Strip District'),
#  Row(city='Strongsville'),
#  Row(city='Strongville'),
#  Row(city='Stuttgart'),
#  Row(city='Stuttgart - Bad Cannstatt'),
#  Row(city='Stuttgart Bad-Canstatt'),
#  Row(city='Stuttgart-Vaihingen'),
#  Row(city='Summerlin'),
#  Row(city='Summerlin South'),
#  Row(city='Sun City'),
#  Row(city='Sun City Anthem'),
#  Row(city='Sun City Grand'),
#  Row(city='Sun City West'),
#  Row(city='Sun Lakes'),
#  Row(city='Sun Prairie'),
#  Row(city='Sunnyslope'),
#  Row(city='Sunrise'),
#  Row(city='Surprise'),
#  Row(city='Swissvale'),
#  Row(city='TORONTO'),
#  Row(city='Tallmadge'),
#  Row(city='Tega Cay'),
#  Row(city='Tempe'),
#  Row(city='Terrebonne'),
#  Row(city='Thorncliffe Park'),
#  Row(city='Thornhil'),
#  Row(city='Thornhill'),
#  Row(city='Tolleson'),
#  Row(city='Tolono'),
#  Row(city='Toronto'),
#  Row(city='Tottenham'),
#  Row(city='Trafford'),
#  Row(city='Tranent'),
#  Row(city='Tremont'),
#  Row(city='Turtle Creek'),
#  Row(city='Tuscola'),
#  Row(city='Twinsburg'),
#  Row(city='Unionville'),
#  Row(city='University Heights'),
#  Row(city='University Ht'),
#  Row(city='University Hts '),
#  Row(city='Upper Saint Clair'),
#  Row(city='Upper St Clair'),
#  Row(city='Upper St. Clair'),
#  Row(city='Urbana'),
#  Row(city='Valley City'),
#  Row(city='Valley View'),
#  Row(city='Vaudreuil-Dorion'),
#  Row(city='Vaughan'),
#  Row(city='Vaughn'),
#  Row(city='Venetia'),
#  Row(city='Verdun'),
#  Row(city='Verona'),
#  Row(city='Vilas'),
#  Row(city='Villa Grove'),
#  Row(city='Vimont'),
#  Row(city='W Henderson'),
#  Row(city='W Spring Valley'),
#  Row(city='W Summerlin'),
#  Row(city='WICKLIFFE'),
#  Row(city='Waddell'),
#  Row(city='Waiblingen'),
#  Row(city='Walton Hills'),
#  Row(city='Warrensvile Heights'),
#  Row(city='Warrensville'),
#  Row(city='Warrensville Heights'),
#  Row(city='Warrensville Hts'),
#  Row(city='Warrensville Hts.'),
#  Row(city='Water of Leith'),
#  Row(city='Waunakee'),
#  Row(city='Waxhaw'),
#  Row(city='Weddington'),
#  Row(city='Wesley Chapel'),
#  Row(city='West Akron'),
#  Row(city='West Bridgewater'),
#  Row(city='West Elizabeth'),
#  Row(city='West Homestead'),
#  Row(city='West Las Vegas'),
#  Row(city='West Mifflin'),
#  Row(city='West Toronto'),
#  Row(city='West View'),
#  Row(city='Westlake'),
#  Row(city='Westmount'),
#  Row(city='Weston'),
#  Row(city='Westworld Scottsdale'),
#  Row(city='Wexford'),
#  Row(city='Whitby'),
#  Row(city='Whitchurch-Stouffville'),
#  Row(city='White Oak'),
#  Row(city='Whitney'),
#  Row(city='Wickliffe'),
#  Row(city='Wildwood'),
#  Row(city='Wilkins Township'),
#  Row(city='Wilkinsburg'),
#  Row(city='Willoughby'),
#  Row(city='Willoughby Hills'),
#  Row(city='Willowdale'),
#  Row(city='Willowick'),
#  Row(city='Wilmerding'),
#  Row(city='Windsor'),
#  Row(city='Wolfschlugen'),
#  Row(city='Woodbridge'),
#  Row(city='Woodbridge (Vaughan)'),
#  Row(city='Woodmere'),
#  Row(city='York'),
#  Row(city='Youngtown'),
#  Row(city='columbia station'),
#  Row(city='etobicoke'),
#  Row(city='frazer'),
#  Row(city='las vegas'),
#  Row(city='mesa'),
#  Row(city='nboulder city'),
#  Row(city='oakville'),
#  Row(city='pleasant hills')]

# %% [markdown]
# ### Choosing a business category
#
# - Define a regular Python function that takes a list of categories and returns 1 if a category of your choice (for instance, 'Restaurants') is contained in the list of categories or 0 otherwise
# - Using the Python function, define a Spark's User Defined Function (UDF) with an IntegerType return
# - Using the UDF, filter the businesses that belong to the category you chose

# %%
from pyspark.sql.functions import UserDefinedFunction
from pyspark.sql.types import IntegerType
from pyspark.sql.types import BooleanType

def is_restaurant(categories):
    return True if 'Restaurants' in categories else 0

is_restaurant_UDF = UserDefinedFunction(lambda x: is_restaurant(x), BooleanType())

df_restaurants = df_business.filter(is_restaurant_UDF(df_business.categories))

# %%
df_restaurants.take(1)
# Out:
# [Row(business_id='EDqCEAGXVGCH4FJXgqtjqg', name='Pizza Pizza', city='Toronto', stars=2.5, categories=['Restaurants', 'Pizza', 'Chicken Wings', 'Italian'], address='979 Bloor Street W')]

# %% [markdown]
# - The UDF approach works just fine, but there is a more straightforward way to perform the same operation
#     - hint: look at ***array_contains*** SQL function

# %%
import pyspark.sql.functions as F

# you can overwrite the former df_restaurants
df_restaurants = df_business.where(F.array_contains('categories','Restaurants'))

# %%
df_restaurants.take(1)
# Out:
# [Row(business_id='EDqCEAGXVGCH4FJXgqtjqg', name='Pizza Pizza', city='Toronto', stars=2.5, categories=['Restaurants', 'Pizza', 'Chicken Wings', 'Italian'], address='979 Bloor Street W')]

# %% [markdown]
# ### Choosing a city
# - Having filtered by the business category, now it is time to filter by the city (for instance, Edinburgh)

# %%
# df_city_restaurants = df_restaurants.where(df_restaurants.city == 'Edinburgh')
df_city_restaurants = df_restaurants.filter('city = "Edinburgh"')

# %%
df_city_restaurants.take(1)
# Out:
# [Row(business_id='NsarUMMMPOlMBb6K04x6hw', name='Juice Almighty', city='Edinburgh', stars=4.5, categories=['Food', 'Fast Food', 'Restaurants', 'Juice Bars & Smoothies'], address='7A Castle Street, Corstorphine')]

# %% [markdown]
# ### Generating numeric IDs
# - If you haven't done it yet, take one sample from your already filtered DataFrame and notice that the ***business_id*** contains an alphanumeric value - this is not good for Spark's ALS implementation, which requires IDs for items (in our case, businesses) and users to be numeric
# - Use a ***StringIndexer*** to create a new column ***business_idn*** from the conversion of business_id into a numeric value

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol='business_id', outputCol='business_idn')
model_index = indexer.fit(df_city_restaurants)

df_city_restaurants = model_index.transform(df_city_restaurants)

# %%
df_city_restaurants.take(1)
# Out:
# [Row(business_id='NsarUMMMPOlMBb6K04x6hw', name='Juice Almighty', city='Edinburgh', stars=4.5, categories=['Food', 'Fast Food', 'Restaurants', 'Juice Bars & Smoothies'], address='7A Castle Street, Corstorphine', business_idn=24.0)]

# %%
df_city_restaurants.cache()
# Out:
# DataFrame[business_id: string, name: string, city: string, stars: double, categories: array<string>, address: string, business_idn: double]

# %% [markdown]
# ## Review Data
#
# - Load the file ***yelp_academic_dataset_review.json*** and select the following columns:
#     - user_id
#     - business_id
#     - stars
#     - date

# %%
df_reviews = sqlc.read.json('./yelp_academic_dataset_review.json')
df_reviews = df_reviews.select(['user_id',
                                 'business_id',
                                 'stars',
                                 'date'])

# %%
df_reviews.take(1)
# Out:
# [Row(user_id='KpkOkG6RIf4Ra25Lhhxf1A', business_id='2aFiy99vNLklCx3T_tGS9A', stars=5, date='2011-10-10')]

# %% [markdown]
# ### Keeping reviews for the chosen city only
#
# - You are only interested in reviews of businesses you kept after filtering for category and city - how to filter out everything else? (hint: take a look at the ***join*** operation of DataFrames)

# %%
df_city_reviews = df_city_restaurants.select('business_id').join(df_reviews, on='business_id')
df_city_reviews = model_index.transform(df_city_reviews)

# %%
df_city_reviews.show(1)
# Out:
# +--------------------+--------------------+-----+----------+------------+
# |         business_id|             user_id|stars|      date|business_idn|
# +--------------------+--------------------+-----+----------+------------+
# |-3pfhzz9CB7F2DpbF...|VRVCKQhYDCkzaEDce...|    5|2008-07-06|      1208.0|
# +--------------------+--------------------+-----+----------+------------+
# only showing top 1 row

# %% [markdown]
# ### Generating numeric IDs
#
# - As it happened with the ***business_id***, you also need to convert ***user_id*** into a numeric value - once again, use a ***StringIndexer*** to create a new column named ***user_idn*** containing the result of the conversion

# %%
indexer_users = StringIndexer(inputCol='user_id', outputCol='user_idn')
model_index_users = indexer_users.fit(df_city_reviews)

df_city_reviews = model_index_users.transform(df_city_reviews)

# %%
df_city_reviews.show(1)
# Out:
# +--------------------+--------------------+-----+----------+------------+--------+
# |         business_id|             user_id|stars|      date|business_idn|user_idn|
# +--------------------+--------------------+-----+----------+------------+--------+
# |-3pfhzz9CB7F2DpbF...|VRVCKQhYDCkzaEDce...|    5|2008-07-06|      1208.0|    63.0|
# +--------------------+--------------------+-----+----------+------------+--------+
# only showing top 1 row

# %%
df_city_reviews.cache()
# Out:
# DataFrame[business_id: string, user_id: string, stars: bigint, date: string, business_idn: double, user_idn: double]

# %% [markdown]
# ### Adding a sequential number to the user's reviews
#
# - Now add a ***sequential number*** to the user's reviews, that is, for each user, order his/her reviews by date (multiple reviews on the same date can be randomly ordered) and number them (hint: check ***window functions***)
# - This sequential number will be useful later to perform a time-wise split of the dataset

# %%
# from pyspark.sql import Window
# from pyspark.sql import functions as F

# w = (Window()
#      .partitionBy('Pclass')
#      .orderBy('Fare')
#      .rowsBetween(-9, 0))

# (train
#  .withColumn('sumFare', F.sum('Fare').over(w))
#  .select('PClass','Fare','sumFare')
#  .show())

# %%
from pyspark.sql import Window

# df_city_reviews = ...

w = (Window()
    .partitionBy('user_idn')
    .orderBy('date')
    .rowsBetween(Window.unboundedPreceding, Window.currentRow))

df_city_reviews = df_city_reviews.withColumn('review_number', F.count('stars').over(w))

# OR

# w = (Window()
#     .partitionBy('user_idn')
#     .orderBy('date'))
# df_city_reviews = df_city_reviews.withColumn('review_number', F.row_number().over(w))

# %%
df_city_reviews.show()
# Out:
# +--------------------+--------------------+-----+----------+------------+--------+-------------+
# |         business_id|             user_id|stars|      date|business_idn|user_idn|review_number|
# +--------------------+--------------------+-----+----------+------------+--------+-------------+
# |sTCI-NaZBkpujXnc-...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       327.0|   299.0|            1|
# |2vOHS-_p5ylEf0BGR...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       144.0|   299.0|            2|
# |5Iin0tl6QJT_TyL1B...|MXdFKeqnoMDj180hl...|    2|2011-05-02|      1047.0|   299.0|            3|
# |xNQj7CamjY9vKp8AC...|MXdFKeqnoMDj180hl...|    4|2011-05-02|       228.0|   299.0|            4|
# |E8PkjCmDnDE7_2rYf...|MXdFKeqnoMDj180hl...|    5|2011-05-19|       942.0|   299.0|            5|
# |483pQIBo1rxjZqms1...|MXdFKeqnoMDj180hl...|    5|2011-05-25|        51.0|   299.0|            6|
# |ckzOUjOGnPKD8NJCc...|MXdFKeqnoMDj180hl...|    3|2011-05-30|       850.0|   299.0|            7|
# |B9gUwTS1_Yzj2vajj...|MXdFKeqnoMDj180hl...|    4|2011-05-30|       703.0|   299.0|            8|
# |0SjdW0AHzE5F5LUYR...|MXdFKeqnoMDj180hl...|    5|2011-06-01|      1336.0|   299.0|            9|
# |4gAdbWT_B7D8HZBms...|MXdFKeqnoMDj180hl...|    5|2011-06-09|       460.0|   299.0|           10|
# |ujUEnwAAhfNOe_LMY...|MXdFKeqnoMDj180hl...|    5|2011-06-10|        75.0|   299.0|           11|
# |EiYE3T3hfqcpcficZ...|MXdFKeqnoMDj180hl...|    4|2011-07-26|       757.0|   299.0|           12|
# |z1RP-_vmj00EunHu9...|hhTEZQNODA7xPLYRy...|    4|2008-08-01|       827.0|   305.0|            1|
# |9wSHuOEou6PkRd-Gb...|hhTEZQNODA7xPLYRy...|    5|2008-08-08|       891.0|   305.0|            2|
# |1oVjBJh3fNfy6_MTd...|hhTEZQNODA7xPLYRy...|    3|2008-08-10|       718.0|   305.0|            3|
# |vA5QW-rVoHCaydHwO...|hhTEZQNODA7xPLYRy...|    5|2008-09-23|       745.0|   305.0|            4|
# |MGOBNMCuhnYRcaiBj...|hhTEZQNODA7xPLYRy...|    4|2008-09-30|       385.0|   305.0|            5|
# |J_KI8rJa_dSwTglUb...|hhTEZQNODA7xPLYRy...|    4|2008-09-30|      1135.0|   305.0|            6|
# |47Uu-2MceSRFmohdz...|hhTEZQNODA7xPLYRy...|    2|2008-09-30|       869.0|   305.0|            7|
# |q9hS_e29155kfo_Se...|hhTEZQNODA7xPLYRy...|    3|2008-11-15|       162.0|   305.0|            8|
# +--------------------+--------------------+-----+----------+------------+--------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Subsetting reviews to keep only users with more than 4 reviews
#
# - Some users had rated only 1 or a few businesses - this would pose as a problem to make recommendations - so you would want to keep only users who had rated more than 4 reviews, for instance
# - Find the ***total number of reviews*** for each user and then filter them using this information (hint: again, you can use a ***window function***)

# %%
selected_users = df_city_reviews.select('user_idn', 'review_number').groupBy('user_idn') \
                    .max().filter('max(review_number) > 4').select('user_idn')

# %%
df_selected = df_city_reviews.join(selected_users, on='user_idn')

# %%
df_selected.cache()
# Out:
# DataFrame[user_idn: double, business_id: string, user_id: string, stars: bigint, date: string, business_idn: double, review_number: bigint]

# %% [markdown]
# ### Calculating mean rating by user
#
# - Now you can calculate the mean rating by user and make it into a dictionary where the key is the ***user_id*** (hint: look at ***rdd*** method of DataFrames and ***collectAsMap*** method of RDDs)

# %%
dict_user_means = df_selected.select('user_id', 'stars').groupBy('user_id').mean().rdd.collectAsMap()

# %%
dict_user_means
# Out:
# {'-0MQ4webH2uc1ZAsGsNENg': 4.2,
#  '-0wDYXGaz2mrHd6fQUvPHQ': 3.8,
#  '-2EcIDIDnA8H7N81jwYpcQ': 3.0,
#  '-4dmE_9lhLi7MOWGI72YhA': 3.6,
#  '-AMiTsraRXFdNX9yBuzWSQ': 4.222222222222222,
#  '-BJTaybCScNgY73ph1TE8Q': 3.8,
#  '-EVgopMWXfIOPHktwc0UBA': 3.0,
#  '-GwqsPQ2WC-dNkjOyJ_FcA': 3.2,
#  '-LP5O6JelPyVS6n2F9JQ7A': 4.0,
#  '-TJhZseJMYZjOab0wMOnAQ': 4.0,
#  '-YVcxGk8zvn3wlCYVKAgsg': 3.8,
#  '-ZBReTMh4DEGjc9XtteCtg': 4.166666666666667,
#  '-ZM78Lp6guNOiE6yJNAJHw': 4.5,
#  '-ZqPTpx9TyyvdAWbajdilA': 3.6666666666666665,
#  '-bT32tHNq7ngqZNA4Tr8jA': 4.0,
#  '-dw8f7FLaUmWR7bfJ_Yf0w': 2.8,
#  '-kvgG65SqvDO5hxCarrz8Q': 3.2,
#  '-y_rXIfDXY4Egh157AJy7g': 4.4,
#  '-z9w3extrIRiyyW2zHDpGQ': 4.285714285714286,
#  '-zhW9UyMKOMuuydi17x7Ag': 3.5,
#  '0-wo7wKN_Rp0Xs6cBMEDJQ': 3.7083333333333335,
#  '02YOZ7OLgXj18Jp9Fu-Fkg': 3.090909090909091,
#  '03p8zXkWRammSu76kGzb6g': 3.769230769230769,
#  '09_FFRjVsCc7pbqG7MxXyA': 2.888888888888889,
#  '0CptBiovyRGXJDQxKL-aww': 3.9375,
#  '0MeivhX0kZCfV3zMtHtk9Q': 4.0,
#  '0Puy6PcLNSBct5uZhCsjBQ': 3.5,
#  '0S2KCUzFvnWvlRWaDMz7Ng': 4.363636363636363,
#  '0l9OanUo7tnqBfLCzpw1Dw': 3.888888888888889,
#  '0lgr88M1Wdzy9iBQbL6L2g': 4.8,
#  '0o1du6ipbqx6eEGYFOGxCQ': 3.8,
#  '0oSxJd1WGRewv7Afv1dKrw': 3.888888888888889,
#  '0rMkjnsRm82lOhyQH_3enQ': 3.909090909090909,
#  '0sGiC_VQubXxFEkg-OLqyw': 3.4285714285714284,
#  '0xozhwBgwlh3AwJvZ1RYkQ': 3.8,
#  '1-UXAFmZILDj_orrac7GPA': 3.75,
#  '1-dmQknIfIwZ6rmXk5r0pA': 3.5,
#  '10RpPp6zKOTkJwE6JE7Ung': 3.875,
#  '13ypZviUQfnDViqSqe6N6w': 3.8,
#  'sZ3mumX9WjJqp6qrjPPUBQ': 3.6,
#  'sbtOWRvGImnYnA-UGOQITA': 4.8,
#  'soDF6mePh1SuNZI3rN7HPQ': 4.25,
#  'szJGIAReInHXt7r8RQxcKg': 3.8,
#  't0lb4ZHHAAt1K10bjXIATg': 3.9473684210526314,
#  't5wQJpxD_8tGusq98hIW1w': 3.5,
#  't8aJIHxkutRlWMRNSvpq6w': 3.8,
#  'tI5jVZ1CGZr2tLt1cwGZ5g': 3.1666666666666665,
#  'tJvy5BkQTZ_si1XvD-luuw': 4.2,
#  'tM-LuoQZFvLw8_pRo5qDcA': 4.2,
#  'tN32hZNKcyo1mVVzgsp7Bw': 3.6666666666666665,
#  'tNwgHQqTm7tIQ0seDM9pZQ': 4.4,
#  'tP4HJxKxCp5S9LMAXli7vg': 3.4,
#  'tQuEVOwokhp63Xl6wEvmqg': 3.789473684210526,
#  'tUdyuqlMqd9Vvs4UuT0gHQ': 3.8333333333333335,
#  'tVrGBW6rj1uebWnqjY-iTQ': 4.361111111111111,
#  'tW50LVGSciU1A4OEQdm63Q': 4.0,
#  'tXIN2tMOAiZH-lGwEaHOkg': 3.5714285714285716,
#  'tiLr51Dh-OZJPl0eOyPraw': 5.0,
#  'tkXqjDH2_3SvEn8QVaJavA': 4.4,
#  'ttf13jziilUWI7PjWqGYYA': 4.428571428571429,
#  'txzOZrHK9EVY0kYjSuXkKg': 3.280701754385965,
#  'u-Vjl1vjSFDg5T_pXR6gBA': 3.5,
#  'u2NjjrFtg4ZMsoDXtDBqjA': 3.8461538461538463,
#  'u8P_KUCD21yVqS6LjnVB0A': 3.8,
#  'uHOQS0jFKEBwP-YfKXAIjw': 4.142857142857143,
#  'uI6fI4oZnt__2gUQNMVVcQ': 4.428571428571429,
#  'uMJ_gLfOuw5Fo4-_giVr2A': 3.8333333333333335,
#  'uTRWF_Hd-Sbc164ixIP8ng': 3.75,
#  'ugVBmapd7bLfXwt2mHx3lA': 2.4,
#  'uh-FpNh4a3gxZWS37rjMFw': 4.2,
#  'unO1U4PV7C4dN5CYZfdaTg': 3.238095238095238,
#  'uop7sZaxJEQInWQTrQCplA': 3.8125,
#  'utRlrauZEOF_2kASsIoJ7A': 3.9558823529411766,
#  'utymPwB_ESYxPzgz7Yh-IA': 3.142857142857143,
#  'v-y68E1spqqt0ZJ6lqCCnQ': 4.166666666666667,
#  'v3nHiuhcD8PTTxL9bfNlOQ': 4.166666666666667,
#  'vQnR9L9HILjw4PgWB8q1cQ': 3.6153846153846154,
#  'v_lWueG7V_vul4E8rCEdjQ': 3.641025641025641,
#  'vbq-811-_beGtp-SSQhC5Q': 4.428571428571429,
#  'vjPS9c7Yt2Vc_gEly-65rQ': 4.375,
#  'vu2Y7kCTtxhNGmjzWMankw': 4.0,
#  'vvQhikDPjAzHfSLVgnFkPQ': 3.721311475409836,
#  'wK7unWb9i25ekCP37sWtfQ': 4.25,
#  'wLNbwYZLqP4KlHDFEgdL4g': 2.6,
#  'wYYVfoYTqV3mHnqwdZ52sQ': 4.0,
#  'wiXl7s8X6kTZeDf_vV-Ylg': 3.0,
#  'wk-QmrbyCtGD23oIhMP44w': 4.148148148148148,
#  'wyYPJrDaI-bV2maaS6v64A': 4.0,
#  'x-9AN426Qpj8TXE6KA_yNw': 4.071428571428571,
#  'x-xinceFIUsjPutqNBiAaQ': 3.5833333333333335,
#  'xBZ1_3ylm3hf3VQHZ3ApFw': 4.0,
#  'xJKnmUxpJfzPovCTsT1kLg': 3.8333333333333335,
#  'xJpvRrk04rb4rgWtMXaPUQ': 4.285714285714286,
#  'xL8TPB74FH44MNc3cokrFA': 4.318181818181818,
#  'xQChZzfGNm743JDEXBq2TA': 4.363636363636363,
#  'xVW2T8jmwg6J99I4bpYUZg': 3.8333333333333335,
#  'xXQTdJXPGOP-NUYctcQw8g': 4.163120567375887,
#  'xYmJTCC4GowUQRsn-q0ZvA': 4.6,
#  'x_B6HetResuFzznXnVyEog': 3.25,
#  'xan14G_7IU66GtQPAA2cKw': 3.590909090909091,
#  'xoGJQ9xNqpMU0GZI_v7Y_A': 4.181818181818182,
#  'xq-9imgF_ueORrZDWxeflw': 3.6,
#  'xwJgGjg_GAMvd5HyO1Ajrg': 3.4871794871794872,
#  'y0mXSJKOi_1y3ZQyXnFGFg': 3.3448275862068964,
#  'y8fGAa_jpXQRdsdwQc_0Kg': 3.0,
#  'yI4LI8-aYYUS9MmrfpidMQ': 3.6875,
#  'yNE7_6V-78CZ2cnmjO5mIw': 4.357142857142857,
#  'yNz6YWwxNUI_ekxZvk3Hdg': 4.0,
#  'yO8_fwzeO0W3-kahJLF1pw': 4.4,
#  'yRm9czxWwbiJA-rtRAigcA': 3.875,
#  'ySM2hhVvRKlEfgw9480yng': 3.857142857142857,
#  'yaBIVHDxaUBN2YHQ8-YiuQ': 4.142857142857143,
#  'ybURek54OkDGsyqWhBmUjQ': 4.1,
#  'yfXqZkU5iXE07GSHzdsQBA': 4.00990099009901,
#  'yhsGx56jGWf2tG7YA834Gg': 4.142857142857143,
#  'ynQgYx_DquFgVMXPxSO-ug': 4.4,
#  'ynreu0XsUdKe3iZMh98hXg': 3.7857142857142856,
#  'yoNEakGPJ5wMmye0_mzDpQ': 4.571428571428571,
#  'yoUk3LhiE-isbRh6OMAPLw': 4.2,
#  'yrGX6Pw3wTO-1xG9TTsIaw': 3.6538461538461537,
#  'ysakeAQj9mknDNeO69-FzQ': 4.0,
#  'ytt8UjH-gvH50GnNmXNokA': 4.75,
#  'yuFHrb8YQtVuzu0eEXvJtA': 3.5641025641025643,
#  'yxplUTyzTXGz0Fj1doXWcA': 2.5833333333333335,
#  'z1STeIy0AqI86F4UyFwScA': 3.923076923076923,
#  'z3Kv50opg6gZ3WwhOxwT-g': 3.5,
#  'z6gJnDrzivFidJMr-4z2VA': 4.0,
#  'zCAtVD9PCNkud9nW-V1Buw': 4.4,
#  'zF-hK3107dbCR9vW_kRTWg': 3.8,
#  'zTzIyjPmGn6gaUiJp2Y7-Q': 4.0,
#  'zUXTdPXno9-V_LVXOGa2sw': 3.625,
#  'zcFy3MIR2wyL6WK2EZDJjA': 3.6,
#  'zekiCxtF-O8gF7agmUQm6g': 3.5454545454545454,
#  'zjj6fK65LRB4WNlE8Qt3lg': 3.8}

# %% [markdown]
# ### Centering rating by user
#
# - The dictionary containing mean ratings by user can be seen as a ***lookup table*** - what is the appropriate way of dealing with those in Spark?
# - Once you have figured this out, define a regular Python function that takes two arguments - ***user_id*** (String) and ***rating*** (String, which you will need to convert to float inside the function) - and returns the result of subtracting the mean rating of the user from the rating parameter
# - Using the Python function, define a Spark's User Defined Function (UDF) with a DoubleType return
# - Using the UDF, create a column in your DataFrame with the centered ratings

# %%
from pyspark.sql.types import DoubleType
# import numpy as np

lookup_user_means = sc.broadcast(dict_user_means)
# lookup_user_means.value['-z9w3extrIRiyyW2zHDpGQ']

def zero_mean(user_id, rating):
    return rating - lookup_user_means.value[user_id]

# zero_mean_UDF = UserDefinedFunction(lambda x,y: zero_mean(x,y), DoubleType())
zero_mean_UDF = UserDefinedFunction(zero_mean, DoubleType())

# df_centered = df_selected.withColumn('centered_rating', zero_mean_UDF(df_selected.user_id,df_selected.stars))
df_centered = df_selected.withColumn('centered_rating', zero_mean_UDF('user_id','stars'))

# %%
df_centered.show(5)
# Out:
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+
# |user_idn|         business_id|             user_id|stars|      date|business_idn|review_number|     centered_rating|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+
# |   299.0|sTCI-NaZBkpujXnc-...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       327.0|            1|   0.666666666666667|
# |   299.0|2vOHS-_p5ylEf0BGR...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       144.0|            2|   0.666666666666667|
# |   299.0|5Iin0tl6QJT_TyL1B...|MXdFKeqnoMDj180hl...|    2|2011-05-02|      1047.0|            3|  -2.333333333333333|
# |   299.0|xNQj7CamjY9vKp8AC...|MXdFKeqnoMDj180hl...|    4|2011-05-02|       228.0|            4|-0.33333333333333304|
# |   299.0|E8PkjCmDnDE7_2rYf...|MXdFKeqnoMDj180hl...|    5|2011-05-19|       942.0|            5|   0.666666666666667|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# - Once again, the UDF approach is not the most "Sparkonic" way of handling this - can you perform the same operation using only functions from ***pyspark.sql.functions*** (which was imported earlier as F)?
#     - hint: you'll need ***Window functions***

# %%
w = Window().partitionBy('user_idn')
#     .rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing))

# df_centered = df_selected.withColumn('centered_rating', df_selected.stars - F.mean('stars').over(w))
df_centered = df_selected.withColumn('centered_rating', df_selected.stars - F.mean('stars').over(w))

# %%
df_centered.show()
# Out:
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+
# |user_idn|         business_id|             user_id|stars|      date|business_idn|review_number|     centered_rating|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+
# |   299.0|sTCI-NaZBkpujXnc-...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       327.0|            1|   0.666666666666667|
------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Splitting into training and test sets by time
#
# - In recommender systems, it is common practice to do the training/test split timewise, that is, the test set is composed of the latest reviews
# - First, filter only those reviews which have a sequential number smaller than the ***total number of reviews***, by user: this is your training set
# - Then, filter only those reviews which have a sequential number identical to the ***total number of reviews***, by user: this is your test set
# - Now you can see why you had to add a sequential number to the user's reiews - since some users had done all his/her reviews on the same day, you need to disambiguate them to split the dataset. By doing this, you guarantee your test set will have only 1 review for each user.

# %%
training_users = df_centered.select('user_idn', 'review_number').groupBy('user_idn') \
                    .max().select('user_idn', F.col('max(review_number)').alias('max_reviews'))

df_training = df_centered.join(training_users, on='user_idn').filter('review_number < max_reviews')
df_training.show(5)

df_test = df_centered.join(training_users, on='user_idn').filter('review_number == max_reviews')
df_test.show(5)
# Out:
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# |user_idn|         business_id|             user_id|stars|      date|business_idn|review_number|     centered_rating|max_reviews|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# |   299.0|sTCI-NaZBkpujXnc-...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       327.0|            1|   0.666666666666667|         12|
# |   299.0|2vOHS-_p5ylEf0BGR...|MXdFKeqnoMDj180hl...|    5|2011-04-20|       144.0|            2|   0.666666666666667|         12|
# |   299.0|5Iin0tl6QJT_TyL1B...|MXdFKeqnoMDj180hl...|    2|2011-05-02|      1047.0|            3|  -2.333333333333333|         12|
# |   299.0|xNQj7CamjY9vKp8AC...|MXdFKeqnoMDj180hl...|    4|2011-05-02|       228.0|            4|-0.33333333333333304|         12|
# |   299.0|E8PkjCmDnDE7_2rYf...|MXdFKeqnoMDj180hl...|    5|2011-05-19|       942.0|            5|   0.666666666666667|         12|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# only showing top 5 rows
#
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# |user_idn|         business_id|             user_id|stars|      date|business_idn|review_number|     centered_rating|max_reviews|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# |   299.0|EiYE3T3hfqcpcficZ...|MXdFKeqnoMDj180hl...|    4|2011-07-26|       757.0|           12|-0.33333333333333304|         12|
# |   305.0|Id9kxJ3VPFq_vNAQb...|hhTEZQNODA7xPLYRy...|    5|2008-11-20|      1389.0|           12|  1.0833333333333335|         12|
# |   496.0|IIWUPx-7qZUgtYBKD...|bhrh6Z03sas3osDNI...|    2|2012-04-15|      1375.0|            7| -0.8571428571428572|          7|
# |   558.0|WUAe0FGaLRCremEDX...|tI5jVZ1CGZr2tLt1c...|    4|2012-09-05|       780.0|            6|  0.8333333333333335|          6|
# |   596.0|Z-9ZLg77FXTQCMqp1...|In46Vl71LOiXa0Pwj...|    5|2014-01-30|       288.0|            6|   0.833333333333333|          6|
# +--------+--------------------+--------------------+-----+----------+------------+-------------+--------------------+-----------+
# only showing top 5 rows

# %% [markdown]
# ### If using Spark 2.1 (as in the Docker image), you need to filter out "new" businesses in the test set

# %%
businesses = df_training.select('business_id').distinct()
df_test = df_test.join(businesses, on='business_id')

# %% [markdown]
# ## Alternate Least Squares (ALS) Model
#
# - This is the recommender itself - the ALS uses a iterative approach to find the underlying factors that yield the user/item rating matrix
# - It takes as input a DataFrame with three columns, representing:
#     - userCol: user IDs (numeric - remember the conversion you did)
#     - itemCol: item IDs (numeric - remember the conversion you did)
#     - ratingCol: rating (numeric, obviously)
#     - coldStartStrategy: "drop" (if there is unseen data on the test set, meaning a new user/business, drop it) - ***only available from Spark 2.2 on***
# - Its parameters are:
#     - rank: the number of factors to consider
#     - maxIter: the maximum number of iterations to perform
#     - regParam: the regularization parameter
# - Use Spark's ALS to fit a model based on your DataFrame

# %%
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator

model = ALS(userCol='user_idn', itemCol='business_idn', ratingCol='centered_rating') \
        .fit(df_training)

# %% [markdown]
# ### Predictions for the training set
#
# - Once the model is trained, make predictions for the training set and use a ***RegressionEvaluator*** to find out the RMSE of the predictions

# %%
predictions = model.transform(df_training)

evaluator = RegressionEvaluator(labelCol='centered_rating')

train_rmse = evaluator.evaluate(predictions)

print(train_rmse)
# Out:
# 0.3830311103577157

# %% [markdown]
# ### Predictions for the test set
#
# - Now, make predictions for the test set and use a ***RegressionEvaluator*** to find out the RMSE of the predictions

# %%
predictions = model.transform(df_test)

evaluator = RegressionEvaluator(labelCol='centered_rating')

test_rmse = evaluator.evaluate(predictions)

print(test_rmse)
# Out:
# 1.0112816082377283

# %% [markdown]
# ## Recommendations
#
# Now, your model is trained, but how can you use it to make recommendations for a given user?

# %% [markdown]
# ### Organizing business data
#
# - It would not make sense to recommend a place the user has already rated, right? So, generate a dictionary where ***user_idn*** is the key and a list of the already rated ***business_idn*** is the value (hint: when aggregating DataFrames, ***collect_list*** is a VERY useful function to turn multiple records into a list)

# %%
from pyspark.sql.functions import collect_list

dict_visited_by_user = ...

# %% [markdown]
# - Besides, recommending a given business_id also does not help much, right? So you need to organize the business data in a way it can be shown to the user.
#     - Define a regular Python function that takes one argument ***row*** (Row type) and returns a dictionary where ***business_idn*** is the key and the value is yet another dictionary with relevant fields (for instance: name, address, stars, categories)
#     - Transform your business DataFrame into an RDD and apply the function you defined - upon collecting, you will end up with a list of dictionaries
#     - Transform this list of dictionaries into a single dictionary

# %%
def rest_to_json(row):
    pass

rest = ...

dict_rest = {k: v for d in rest for k, v in d.items()}

# %% [markdown]
# ### Making recommendations for a user
#
# - To actually make the recommendations, we need to build an input DataFrame to feed the model
#     - A DataFrame can be created using the SQL Context and a list of Rows, each containg two columns: user_idn and business_idn - the rating will be computed by the model
#     - But you only need to have rows for the businesses which were not yet rated by the user - from all businesses, exclude the ones already rated by him/her

# %%
from pyspark.sql import Row
from pyspark.sql.functions import desc

user_idn = 317
n_business = len(dict_rest)

visited = ...
not_visited = ...

df_test_user = ...

# %% [markdown]
# - Now, you can use the generated DataFrame to make predictions
#     - If there are any NA predictions, make sure to turn them into a really bad value (for instance, -5.0) (hint: remember ***na*** method of DataFrames)
# - Order the predictions and take the ***business_idn*** of the top 5
# - Finally, use this information to fetch the business data from the dictionary you assembled a couple of steps ago

# %%
predictions = ...

top_predictions = ...

response = list(map(lambda idn: dict_rest[idn], top_predictions))

# %%
response

# %% [markdown]
# ## Congratulations, you finished the exercise!

# %%
sc.stop()
